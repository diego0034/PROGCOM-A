# %% [markdown]
# ##1. FileNotFoundError
# El archivo no se encuentra en la misma carpeta que el programa. Acabo de replicar el mismo código.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. NameError
# Salta cuando te equivocas en la gramática de python. ejemplo se te olvidan las comillas.

# %%
colores[len(colores)-9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c0e17d6de582> in <module>
# ----> 1 colores[len(colores)-9]
#
# NameError: name 'colores' is not defined

# %%
if pwd == 'manzana':
    print('Iniciando sesión ...')
else:
    print('Contraseña incorrecta.')

print('¡Todo terminado!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3c34d569115b> in <module>
# ----> 1 if pwd == 'manzana':
#       2     print('Iniciando sesión ...')
#       3 else:
#       4     print('Contraseña incorrecta.')
#       5
#
# NameError: name 'pwd' is not defined

# %%
for n in range(1):
  print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a97ba75eaecf> in <module>
#       1 for n in range(1):
# ----> 2   print(t)
#
# NameError: name 't' is not defined

# %%
nombre=input("Escribe tu nombre")
print(nombres)
# Out:
# Escribe tu nombreDiego
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-10aaf9e5bee7> in <module>
#       1 nombre=input("Escribe tu nombre")
# ----> 2 print(nombres)
#
# NameError: name 'nombres' is not defined

# %%
dpaises="BRAZIL","VENEZUELA","PERÚ", "ESPAÑA"
paises[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8d839a3443fb> in <module>
#       1 dpaises="BRAZIL","VENEZUELA","PERÚ", "ESPAÑA"
# ----> 2 paises[-1]
#
# NameError: name 'paises' is not defined

# %%
for nnombres in range(1):
  print(w) 
nombres=input("Escribe tu nombre")
print(nombres)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e12dac16072b> in <module>
#       1 for nnombres in range(1):
# ----> 2   print(w)
#       3 nombres=input("Escribe tu nombre")
#       4 print(nombres)
#
# NameError: name 'w' is not defined

# %%
objetos={"animal":["vaca","pato","babilla"],"flores":"rosas","booleano":False}
colores[len(colores)-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-11a0261869dd> in <module>
#       1 objetos={"animal":["vaca","pato","babilla"],"flores":"rosas","booleano":False}
# ----> 2 colores[len(colores)-1]
#
# NameError: name 'colores' is not defined

# %% [markdown]
# ## 3. IndentationError
# Este tiene que ver con las posiciones de las líneas de código para Python, la regla es tener 4 espacios para sangrar. No mezcles con 2,3,5 o una cantidad diferente de espacios ya que Python simplemente no ejecutará tu programa.

# %%
try:
  x=int(input("Escribe un numero"))
   except ValueError:
  print("Numero no válido")
# Out:
#   File "<ipython-input-40-cf8ca61c6dc1>", line 3
#     except ValueError:
#     ^
# IndentationError: unexpected indent

# %%
try:
     l = ["a", "b"]
    int(l[2])
  except ValueError, IndexError:  # To catch both exceptions, right?
    pass
# Out:
#   File "<tokenize>", line 3
#     int(l[2])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
   for pos in range(n):
print(pos=, pos)
# Out:
#   File "<ipython-input-55-7ae25d4670fd>", line 2
#     print(pos=, pos)
#         ^
# IndentationError: expected an indented block

# %%
   while False:
input("HOLA MUNDO")
# Out:
#   File "<ipython-input-58-5d481e74ceaf>", line 2
#     input("HOLA MUNDO")
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# ##4- SyntaxError
# Salta cuando te equivocas en la gramática de python. ejemplo se te olvidan las comillas.

# %%
print “Bienvenido al traductor de espanol a Pig Latin.”

original = raw_input(“Ingrese una palabra: “) longitud = len(original)

if longitud != 0: ….print original else: ….print “Vacio
# Out:
#   File "<ipython-input-17-783c301c13e5>", line 1
#     print “Bienvenido al traductor de espanol a Pig Latin.”
#                     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(“Bienvenido al traductor de espanol a Pig Latin.”)?

# %%
for pos in range(n):
  print(pos=, pos)
# Out:
#   File "<ipython-input-37-73860563ae06>", line 2
#     print(pos=, pos)
#               ^
# SyntaxError: invalid syntax

# %%
a=int(3)
if x==3:
 print(int(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-c5957ca5a670> in <module>
#       1 a=int(3)
#       2 if x==3:
# ----> 3  print(int(a))
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(end=" ", "Mi nombre","Python")
# Out:
#   File "<ipython-input-39-e50329e2bacd>", line 1
#     print(end=" ", "Mi nombre","Python")
#                   ^
# SyntaxError: positional argument follows keyword argument

# %%
for nnombres in range(1):
  print(w)" 
nombres=input("Escribe tu nombre")
print(nombres)
# Out:
#   File "<ipython-input-29-8f209ddb220e>", line 2
#     print(w)"
#               ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ##5- Type error
# Ocurre cuando se aplica una operación o función a un objeto de tipo inapropiado. ejemplo cuando se necesita un string y no un integer.

# %%
x=8
,print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5a1a48a82f86> in <module>
#       1 x=8
# ----> 2 print(x)("")
#
# TypeError: 'str' object is not callable

# %%
a="hola"
print(a),
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-d5c9a8f24a8d> in <module>
#       1 a="hola"
# ----> 2 print(a),
#
# TypeError: 'str' object is not callable

# %%
for nombres in range(1):
  print(nombres), 
nombres=input("Escribe tu nombre")
print(nombres)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b8fce7c737eb> in <module>
#       1 for nombres in range(1):
# ----> 2   print(nombres),
#       3 nombres=input("Escribe tu nombre")
#       4 print(nombres)
#
# TypeError: 'str' object is not callable
